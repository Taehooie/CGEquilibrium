# %%
import jax
import jax.numpy as jnp
import pandas as pd
from jax import grad, jit

from jax import random
key = random.PRNGKey(10)

import scipy
import numpy as np
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
# Variables to be optimized (initial settings)
c_d = 20.0
x_path1 =  79.33806311
x_path2 =  125.1719369

# Initialize Lagrange multipliers
lambda_1 = 0.0
lambda_2 = 0.0
lambda_list = [lambda_1, lambda_2]

@jit
def obj_func(access_cost, x_paths, lambda_list):

    '''
    Return
        Compute the loss function of the augmented lagrangian relaxation
        
    Parameters
    ----------
    access_cost : numpy.array
        The updated accessibility cost (nx1)
    x_paths : numpy.array
        The updated path flows of the two-link network (nx2)
    lambda_list : numpy.array
        The updated lagrangian multipliers (nx2)
    
    '''
    tot_origin_flow = 300.0 # assumption: travelers are selecting the auto-mode
    theta = 1.0
    transit_cost = 25.0

    auto_probs = (jnp.exp(-theta*access_cost[0])/(jnp.exp(-theta*access_cost[0])+jnp.exp(-theta*transit_cost)))

    # Link function parameters
    ttff_1, cap_1 = 20, 4500
    ttff_2, cap_2 = 30, 3000

    # Link travel time function (BPR)
    t_1 = ttff_1*(1 + 0.15*(x_paths[0]/cap_1)**4)
    t_2 = ttff_2*(1 + 0.15*(x_paths[1]/cap_2)**4)

    # Path flow travel time
    t_p1 = t_1
    t_p2 = t_2

    # compute min of travel time
    c_s =  jnp.min(jnp.array([t_p1, t_p2]))

    # Volume
    tot_vol = tot_origin_flow*auto_probs
    path_x = jnp.stack([x_paths[0], x_paths[1]], 0) #prediction

    # # Time
    cost_demand = access_cost[0]
    path_t = jnp.stack([t_p1, t_p2], 0) 

    # Constraints to penalize the costs
    link_condi = access_cost[0] - c_s # integrate demand and supply (c_d - c_s)
    flow_condi = tot_vol - x_paths[0] -  x_paths[1] # flow constraint

    ested_val = [path_x, 
                 path_t, 
                 c_s, 
                 link_condi, 
                 flow_condi]
    
    rho_ = 0.001
    # 0.01 indicates the arbitrary rho value
    loss = path_x[0]*(path_t[0] - c_s) + path_x[1]*(path_t[0] - c_s) + \
           lambda_list[0]*link_condi + rho_*link_condi**2 + lambda_list[1]*flow_condi + rho_*flow_condi**2

    return loss 

@jit
def lambda_condi(up_access_cost, up_x_paths, lambda_list):
    '''
    Return
        Update the lagrangian multipliers corresponding to the accessibility cost and the optimal path flows
        
    Parameters
    ----------
    up_access_cost : numpy.array
        The updated accessibility cost (nx1)
    up_x_paths : numpy.array
        The updated path flows of the two-link network (nx2)
    lambda_list : numpy.array
        The updated lagrangian multipliers (nx2)

    '''
    tot_origin_flow = 300.0 
    theta = 1.0
    transit_cost = 25.0

    auto_probs = (jnp.exp(-theta*up_access_cost[0])/(jnp.exp(-theta*up_access_cost[0])+jnp.exp(-theta*transit_cost)))

    # Link function parameters
    ttff_1, cap_1 = 20, 4500
    ttff_2, cap_2 = 30, 3000

    # Link travel time function (BPR)
    t_1 = ttff_1*(1 + 0.15*(up_x_paths[0]/cap_1)**4)
    t_2 = ttff_2*(1 + 0.15*(up_x_paths[1]/cap_2)**4)

    # Path flow travel time
    t_p1 = t_1
    t_p2 = t_2

    # compute min of travel time
    c_s =  jnp.min(jnp.array([t_p1, t_p2]))
    
    # Volume
    tot_vol = tot_origin_flow*auto_probs

    # # Time
    cost_demand = up_access_cost[0]
    path_t = jnp.stack([t_p1, t_p2], 0) 
    print(cost_demand)
    # Constraints to penalize the costs
    link_condi = up_access_cost[0] - c_s # integrate demand and supply (c_d - c_s)
    flow_condi = tot_vol - up_x_paths[0] -  up_x_paths[1] # flow constraint
    
    ested_val = [link_condi, flow_condi]
    
    rho_ = 0.001
    lambda_list[0] = lambda_list[0] + rho_ * link_condi
    lambda_list[1] = lambda_list[1] + rho_ * flow_condi
    
    return lambda_list

# %%
"""TO DO: Formulate the convergence check function and replace 'for' loop to 'while' """
# Initialize the accessibility cost and the path flows
access_cost = jnp.array([c_d])
x_paths  = jnp.array([x_path1, x_path2])
for i in range(200):
    '''
    Loop over the augmented lagrangian relaxation using the ADMM algorithm
    
    1. Update the accessibility cost
    2. Update the path flows 
    3. Update the lagrangian multipliers
    
    '''
    # Optimization to train the demand component # compute c_d(k+1) fixing x(k)
    train_demand = scipy.optimize.minimize(obj_func, 
                                             access_cost, 
                                             jac  = jit(jax.grad(obj_func)),
                                             args = (x_paths, lambda_list),
                                             method='BFGS')
    updated_cost = jnp.array(train_demand.x)

    # set up the shape of the variables
    access_cost = jnp.array(train_demand.x) # compute a list of x(k+1) by fixing c_d(k+1)
    x_paths  = jnp.array([x_path1, x_path2])
    # Optimization to train the supply component
    train_supply = scipy.optimize.minimize(obj_func, 
                                             x_paths, 
                                             jac  = jit(jax.grad(obj_func)),
                                             args = (updated_cost, lambda_list),
                                             method='BFGS')

    updated_paths = train_supply.x
    # After this step, we update c_d(k) -> c_d(k+1) and x_s(k) -> x_s(k+1).
    # Then the next step is updating the lambda value (\lambda(k) -> \lambda(k+1))
    # lambda(k+1) = lambda(k) + rho*(defined conditions(e.g., link_condi or flow_condi))
    updated_lambdas = lambda_condi(updated_cost, updated_paths, lambda_list)
    
    # Reassign the updated parameters and variables including the lagrangian multipliers
    lambda_list = updated_lambdas
    access_cost = updated_cost
    x_paths = updated_paths
    
    # Print out the sequentially updated results
    print('iteration_step:', i)
    print('1. Updating the generalized travel costs:', updated_cost)
    print('2. Updating the optimal path flows:', updated_paths)
    print('3. Updating the lambda multiplier for the cost linkage:', lambda_list[0])
    print('4. Updating the lambda multiplier for the flow balance:', lambda_list[1])
    print()
# Out:
# Traced<ShapedArray(float32[])>with<DynamicJaxprTrace(level=0/1)>
# iteration_step: 0
# 1. Updating the generalized travel costs: [24.237404]
# 2. Updating the optimal path flows: [ 26.64249435 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.004237404
# 4. Updating the lambda multiplier for the flow balance: 0.052760713
#
# Traced<ShapedArray(float32[])>with<DynamicJaxprTrace(level=0/1)>
# iteration_step: 1
# 1. Updating the generalized travel costs: [25.329124]
# 2. Updating the optimal path flows: [ 27.41113208 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.009566529
# 4. Updating the lambda multiplier for the flow balance: 0.025713753
#
# iteration_step: 2
# 1. Updating the generalized travel costs: [25.13542]
# 2. Updating the optimal path flows: [ 26.93773747 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.0147019485
# 4. Updating the lambda multiplier for the flow balance: 0.013463081
#
# iteration_step: 3
# 1. Updating the generalized travel costs: [25.059404]
# 2. Updating the optimal path flows: [ 26.76726183 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.019761354
# 4. Updating the lambda multiplier for the flow balance: 0.007069869
#
# iteration_step: 4
# 1. Updating the generalized travel costs: [25.018627]
# 2. Updating the optimal path flows: [ 26.68524871 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.024779981
# 4. Updating the lambda multiplier for the flow balance: 0.003815688
#
# iteration_step: 5
# 1. Updating the generalized travel costs: [24.997583]
# 2. Updating the optimal path flows: [ 26.64452967 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.029777564
# 4. Updating the lambda multiplier for the flow balance: 0.0021804646
#
# iteration_step: 6
# 1. Updating the generalized travel costs: [24.986803]
# 2. Updating the optimal path flows: [ 26.6237961  125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.034764368
# 4. Updating the lambda multiplier for the flow balance: 0.0013744876
#
# iteration_step: 7
# 1. Updating the generalized travel costs: [24.981247]
# 2. Updating the optimal path flows: [ 26.61295405 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.039745614
# 4. Updating the lambda multiplier for the flow balance: 0.0009960391
#
# iteration_step: 8
# 1. Updating the generalized travel costs: [24.978422]
# 2. Updating the optimal path flows: [ 26.60719947 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.044724036
# 4. Updating the lambda multiplier for the flow balance: 0.00083517336
#
# iteration_step: 9
# 1. Updating the generalized travel costs: [24.976984]
# 2. Updating the optimal path flows: [ 26.60395249 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.04970102
# 4. Updating the lambda multiplier for the flow balance: 0.0007854144
#
# iteration_step: 10
# 1. Updating the generalized travel costs: [24.976254]
# 2. Updating the optimal path flows: [ 26.60199399 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.054677274
# 4. Updating the lambda multiplier for the flow balance: 0.0007923801
#
# iteration_step: 11
# 1. Updating the generalized travel costs: [24.975883]
# 2. Updating the optimal path flows: [ 26.60068972 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.05965316
# 4. Updating the lambda multiplier for the flow balance: 0.0008284061
#
# iteration_step: 12
# 1. Updating the generalized travel costs: [24.975698]
# 2. Updating the optimal path flows: [ 26.59972773 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.064628854
# 4. Updating the lambda multiplier for the flow balance: 0.00087927125
#
# iteration_step: 13
# 1. Updating the generalized travel costs: [24.975609]
# 2. Updating the optimal path flows: [ 26.59893888 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.069604464
# 4. Updating the lambda multiplier for the flow balance: 0.00093764375
#
# iteration_step: 14
# 1. Updating the generalized travel costs: [24.975569]
# 2. Updating the optimal path flows: [ 26.59823111 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.074580036
# 4. Updating the lambda multiplier for the flow balance: 0.0009997317
#
# iteration_step: 15
# 1. Updating the generalized travel costs: [24.975548]
# 2. Updating the optimal path flows: [ 26.597575   125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.079555586
# 4. Updating the lambda multiplier for the flow balance: 0.0010640476
#
# iteration_step: 16
# 1. Updating the generalized travel costs: [24.975546]
# 2. Updating the optimal path flows: [ 26.59694322 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.08453113
# 4. Updating the lambda multiplier for the flow balance: 0.0011291415
#
# iteration_step: 17
# 1. Updating the generalized travel costs: [24.975546]
# 2. Updating the optimal path flows: [ 26.59631947 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.08950667
# 4. Updating the lambda multiplier for the flow balance: 0.0011948536
#
# iteration_step: 18
# 1. Updating the generalized travel costs: [24.975546]
# 2. Updating the optimal path flows: [ 26.59580941 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.09448221
# 4. Updating the lambda multiplier for the flow balance: 0.0012610768
#
# iteration_step: 19
# 1. Updating the generalized travel costs: [24.975546]
# 2. Updating the optimal path flows: [ 26.59512584 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.099457756
# 4. Updating the lambda multiplier for the flow balance: 0.0013279866
#
# iteration_step: 20
# 1. Updating the generalized travel costs: [24.975569]
# 2. Updating the optimal path flows: [ 26.59450454 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.10443333
# 4. Updating the lambda multiplier for the flow balance: 0.0013937978
#
# iteration_step: 21
# 1. Updating the generalized travel costs: [24.975569]
# 2. Updating the optimal path flows: [ 26.59389043 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.1094089
# 4. Updating the lambda multiplier for the flow balance: 0.001460227
#
# iteration_step: 22
# 1. Updating the generalized travel costs: [24.975573]
# 2. Updating the optimal path flows: [ 26.59328788 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.11438447
# 4. Updating the lambda multiplier for the flow balance: 0.0015269689
#
# iteration_step: 23
# 1. Updating the generalized travel costs: [24.975573]
# 2. Updating the optimal path flows: [ 26.59269382 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.119360045
# 4. Updating the lambda multiplier for the flow balance: 0.001594306
#
# iteration_step: 24
# 1. Updating the generalized travel costs: [24.975586]
# 2. Updating the optimal path flows: [ 26.59210731 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.12433563
# 4. Updating the lambda multiplier for the flow balance: 0.001661231
#
# iteration_step: 25
# 1. Updating the generalized travel costs: [24.975586]
# 2. Updating the optimal path flows: [ 26.59151625 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.12931122
# 4. Updating the lambda multiplier for the flow balance: 0.0017287435
#
# iteration_step: 26
# 1. Updating the generalized travel costs: [24.975586]
# 2. Updating the optimal path flows: [ 26.59093394 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.1342868
# 4. Updating the lambda multiplier for the flow balance: 0.0017968359
#
# iteration_step: 27
# 1. Updating the generalized travel costs: [24.975607]
# 2. Updating the optimal path flows: [ 26.59047607 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.13926241
# 4. Updating the lambda multiplier for the flow balance: 0.0018638144
#
# iteration_step: 28
# 1. Updating the generalized travel costs: [24.975607]
# 2. Updating the optimal path flows: [ 26.58977085 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.14423801
# 4. Updating the lambda multiplier for the flow balance: 0.0019315024
#
# iteration_step: 29
# 1. Updating the generalized travel costs: [24.975622]
# 2. Updating the optimal path flows: [ 26.58919327 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.14921363
# 4. Updating the lambda multiplier for the flow balance: 0.0019986182
# iteration_step: 30
# 1. Updating the generalized travel costs: [24.975622]
# 2. Updating the optimal path flows: [ 26.58861162 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.15418924
# 4. Updating the lambda multiplier for the flow balance: 0.0020663214
#
# iteration_step: 31
# 1. Updating the generalized travel costs: [24.975706]
# 2. Updating the optimal path flows: [ 26.58790059 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.15916495
# 4. Updating the lambda multiplier for the flow balance: 0.00212844
#
# iteration_step: 32
# 1. Updating the generalized travel costs: [24.975702]
# 2. Updating the optimal path flows: [ 26.58739473 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.16414066
# 4. Updating the lambda multiplier for the flow balance: 0.002191352
#
# iteration_step: 33
# 1. Updating the generalized travel costs: [24.975677]
# 2. Updating the optimal path flows: [ 26.58699857 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.16911633
# 4. Updating the lambda multiplier for the flow balance: 0.0022565147
#
# iteration_step: 34
# 1. Updating the generalized travel costs: [24.97567]
# 2. Updating the optimal path flows: [ 26.58617069 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.17409201
# 4. Updating the lambda multiplier for the flow balance: 0.0023230813
#
# iteration_step: 35
# 1. Updating the generalized travel costs: [24.97567]
# 2. Updating the optimal path flows: [ 26.58559017 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.17906769
# 4. Updating the lambda multiplier for the flow balance: 0.0023902275
#
# iteration_step: 36
# 1. Updating the generalized travel costs: [24.97567]
# 2. Updating the optimal path flows: [ 26.5850892  125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.18404336
# 4. Updating the lambda multiplier for the flow balance: 0.0024578774
#
# iteration_step: 37
# 1. Updating the generalized travel costs: [24.975685]
# 2. Updating the optimal path flows: [ 26.58444624 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.18901905
# 4. Updating the lambda multiplier for the flow balance: 0.0025250237
#
# iteration_step: 38
# 1. Updating the generalized travel costs: [24.975727]
# 2. Updating the optimal path flows: [ 26.58387157 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.19399478
# 4. Updating the lambda multiplier for the flow balance: 0.0025895988
#
# iteration_step: 39
# 1. Updating the generalized travel costs: [24.975727]
# 2. Updating the optimal path flows: [ 26.58326582 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.1989705
# 4. Updating the lambda multiplier for the flow balance: 0.0026547767
#
# iteration_step: 40
# 1. Updating the generalized travel costs: [24.975721]
# 2. Updating the optimal path flows: [ 26.58267939 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.20394622
# 4. Updating the lambda multiplier for the flow balance: 0.0027209693
#
# iteration_step: 41
# 1. Updating the generalized travel costs: [24.975727]
# 2. Updating the optimal path flows: [ 26.58209865 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.20892194
# 4. Updating the lambda multiplier for the flow balance: 0.0027873146
#
# iteration_step: 42
# 1. Updating the generalized travel costs: [24.975727]
# 2. Updating the optimal path flows: [ 26.58152422 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.21389766
# 4. Updating the lambda multiplier for the flow balance: 0.002854232
#
# iteration_step: 43
# 1. Updating the generalized travel costs: [24.975733]
# 2. Updating the optimal path flows: [ 26.58085628 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.2188734
# 4. Updating the lambda multiplier for the flow balance: 0.0029213936
#
# iteration_step: 44
# 1. Updating the generalized travel costs: [24.975733]
# 2. Updating the optimal path flows: [ 26.58040406 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.22384913
# 4. Updating the lambda multiplier for the flow balance: 0.0029890053
#
# iteration_step: 45
# 1. Updating the generalized travel costs: [24.975733]
# 2. Updating the optimal path flows: [ 26.57983521 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.22882487
# 4. Updating the lambda multiplier for the flow balance: 0.0030571816
#
# iteration_step: 46
# 1. Updating the generalized travel costs: [24.975733]
# 2. Updating the optimal path flows: [ 26.57920605 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.2338006
# 4. Updating the lambda multiplier for the flow balance: 0.0031259912
#
# iteration_step: 47
# 1. Updating the generalized travel costs: [24.975733]
# 2. Updating the optimal path flows: [ 26.57874547 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.23877634
# 4. Updating the lambda multiplier for the flow balance: 0.0031952586
#
# iteration_step: 48
# 1. Updating the generalized travel costs: [24.97584]
# 2. Updating the optimal path flows: [ 26.57819084 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.24375218
# 4. Updating the lambda multiplier for the flow balance: 0.0032570718
#
# iteration_step: 49
# 1. Updating the generalized travel costs: [24.975811]
# 2. Updating the optimal path flows: [ 26.57757919 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.24872799
# 4. Updating the lambda multiplier for the flow balance: 0.0033216395
#
# iteration_step: 50
# 1. Updating the generalized travel costs: [24.975811]
# 2. Updating the optimal path flows: [ 26.57699307 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.2537038
# 4. Updating the lambda multiplier for the flow balance: 0.0033867946
#
# iteration_step: 51
# 1. Updating the generalized travel costs: [24.975817]
# 2. Updating the optimal path flows: [ 26.57629019 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.25867963
# 4. Updating the lambda multiplier for the flow balance: 0.0034522242
#
# iteration_step: 52
# 1. Updating the generalized travel costs: [24.975817]
# 2. Updating the optimal path flows: [ 26.57605134 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.26365545
# 4. Updating the lambda multiplier for the flow balance: 0.0035178903
#
# iteration_step: 53
# 1. Updating the generalized travel costs: [24.975817]
# 2. Updating the optimal path flows: [ 26.57526591 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.26863128
# 4. Updating the lambda multiplier for the flow balance: 0.0035843423
#
# iteration_step: 54
# 1. Updating the generalized travel costs: [24.975817]
# 2. Updating the optimal path flows: [ 26.57470571 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.2736071
# 4. Updating the lambda multiplier for the flow balance: 0.003651359
#
# iteration_step: 55
# 1. Updating the generalized travel costs: [24.975817]
# 2. Updating the optimal path flows: [ 26.57415209 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.27858293
# 4. Updating the lambda multiplier for the flow balance: 0.0037189247
#
# iteration_step: 56
# 1. Updating the generalized travel costs: [24.975828]
# 2. Updating the optimal path flows: [ 26.57360763 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.28355876
# 4. Updating the lambda multiplier for the flow balance: 0.0037861778
#
# iteration_step: 57
# 1. Updating the generalized travel costs: [24.97587]
# 2. Updating the optimal path flows: [ 26.5730544  125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.28853464
# 4. Updating the lambda multiplier for the flow balance: 0.003850837
#
# iteration_step: 58
# 1. Updating the generalized travel costs: [24.975868]
# 2. Updating the optimal path flows: [ 26.57249253 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.2935105
# 4. Updating the lambda multiplier for the flow balance: 0.003916206
#
# iteration_step: 59
# 1. Updating the generalized travel costs: [24.975868]
# 2. Updating the optimal path flows: [ 26.57190987 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.29848635
# 4. Updating the lambda multiplier for the flow balance: 0.003982154
# iteration_step: 60
# 1. Updating the generalized travel costs: [24.975868]
# 2. Updating the optimal path flows: [ 26.57134942 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.3034622
# 4. Updating the lambda multiplier for the flow balance: 0.0040486595
#
# iteration_step: 61
# 1. Updating the generalized travel costs: [24.975868]
# 2. Updating the optimal path flows: [ 26.57074683 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.30843806
# 4. Updating the lambda multiplier for the flow balance: 0.004115768
#
# iteration_step: 62
# 1. Updating the generalized travel costs: [24.975876]
# 2. Updating the optimal path flows: [ 26.57025715 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.31341395
# 4. Updating the lambda multiplier for the flow balance: 0.0041827997
#
# iteration_step: 63
# 1. Updating the generalized travel costs: [24.97592]
# 2. Updating the optimal path flows: [ 26.56971195 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.31838986
# 4. Updating the lambda multiplier for the flow balance: 0.004247085
#
# iteration_step: 64
# 1. Updating the generalized travel costs: [24.97592]
# 2. Updating the optimal path flows: [ 26.56913293 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.32336578
# 4. Updating the lambda multiplier for the flow balance: 0.0043119504
#
# iteration_step: 65
# 1. Updating the generalized travel costs: [24.97592]
# 2. Updating the optimal path flows: [ 26.56856508 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.3283417
# 4. Updating the lambda multiplier for the flow balance: 0.00437738
#
# iteration_step: 66
# 1. Updating the generalized travel costs: [24.9759]
# 2. Updating the optimal path flows: [ 26.56801887 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.3333176
# 4. Updating the lambda multiplier for the flow balance: 0.004444786
#
# iteration_step: 67
# 1. Updating the generalized travel costs: [24.9759]
# 2. Updating the optimal path flows: [ 26.56750814 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.33829352
# 4. Updating the lambda multiplier for the flow balance: 0.0045127026
#
# iteration_step: 68
# 1. Updating the generalized travel costs: [24.9759]
# 2. Updating the optimal path flows: [ 26.56694507 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.34326944
# 4. Updating the lambda multiplier for the flow balance: 0.004581184
#
# iteration_step: 69
# 1. Updating the generalized travel costs: [24.9759]
# 2. Updating the optimal path flows: [ 26.56643356 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.34824535
# 4. Updating the lambda multiplier for the flow balance: 0.004650177
#
# iteration_step: 70
# 1. Updating the generalized travel costs: [24.9759]
# 2. Updating the optimal path flows: [ 26.5658867  125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.35322127
# 4. Updating the lambda multiplier for the flow balance: 0.004719719
#
# iteration_step: 71
# 1. Updating the generalized travel costs: [24.976007]
# 2. Updating the optimal path flows: [ 26.56534763 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.35819727
# 4. Updating the lambda multiplier for the flow balance: 0.004781784
#
# iteration_step: 72
# 1. Updating the generalized travel costs: [24.976007]
# 2. Updating the optimal path flows: [ 26.56474862 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.36317328
# 4. Updating the lambda multiplier for the flow balance: 0.004844452
#
# iteration_step: 73
# 1. Updating the generalized travel costs: [24.97599]
# 2. Updating the optimal path flows: [ 26.56413307 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.36814928
# 4. Updating the lambda multiplier for the flow balance: 0.0049090195
#
# iteration_step: 74
# 1. Updating the generalized travel costs: [24.97596]
# 2. Updating the optimal path flows: [ 26.56382402 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.37312526
# 4. Updating the lambda multiplier for the flow balance: 0.0049761888
#
# iteration_step: 75
# 1. Updating the generalized travel costs: [24.97597]
# 2. Updating the optimal path flows: [ 26.56314901 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.37810123
# 4. Updating the lambda multiplier for the flow balance: 0.00504332
#
# iteration_step: 76
# 1. Updating the generalized travel costs: [24.975994]
# 2. Updating the optimal path flows: [ 26.56275066 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.38307723
# 4. Updating the lambda multiplier for the flow balance: 0.005108986
#
# iteration_step: 77
# 1. Updating the generalized travel costs: [24.975994]
# 2. Updating the optimal path flows: [ 26.56206214 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.38805324
# 4. Updating the lambda multiplier for the flow balance: 0.005175339
#
# iteration_step: 78
# 1. Updating the generalized travel costs: [24.975994]
# 2. Updating the optimal path flows: [ 26.56152075 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.39302924
# 4. Updating the lambda multiplier for the flow balance: 0.0052422336
#
# iteration_step: 79
# 1. Updating the generalized travel costs: [24.97601]
# 2. Updating the optimal path flows: [ 26.56099064 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.39800525
# 4. Updating the lambda multiplier for the flow balance: 0.0053085177
#
# iteration_step: 80
# 1. Updating the generalized travel costs: [24.97601]
# 2. Updating the optimal path flows: [ 26.56061506 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.40298125
# 4. Updating the lambda multiplier for the flow balance: 0.0053751757
#
# iteration_step: 81
# 1. Updating the generalized travel costs: [24.976023]
# 2. Updating the optimal path flows: [ 26.55992492 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.4079573
# 4. Updating the lambda multiplier for the flow balance: 0.005441521
#
# iteration_step: 82
# 1. Updating the generalized travel costs: [24.976023]
# 2. Updating the optimal path flows: [ 26.5594103  125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.41293332
# 4. Updating the lambda multiplier for the flow balance: 0.0055083847
#
# iteration_step: 83
# 1. Updating the generalized travel costs: [24.976023]
# 2. Updating the optimal path flows: [ 26.5589116  125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.41790935
# 4. Updating the lambda multiplier for the flow balance: 0.0055757444
#
# iteration_step: 84
# 1. Updating the generalized travel costs: [24.976023]
# 2. Updating the optimal path flows: [ 26.55858487 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.4228854
# 4. Updating the lambda multiplier for the flow balance: 0.0056434325
#
# iteration_step: 85
# 1. Updating the generalized travel costs: [24.976023]
# 2. Updating the optimal path flows: [ 26.55785581 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.42786142
# 4. Updating the lambda multiplier for the flow balance: 0.005711845
#
# iteration_step: 86
# 1. Updating the generalized travel costs: [24.976023]
# 2. Updating the optimal path flows: [ 26.55753472 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.43283746
# 4. Updating the lambda multiplier for the flow balance: 0.005780578
#
# iteration_step: 87
# 1. Updating the generalized travel costs: [24.976023]
# 2. Updating the optimal path flows: [ 26.55678417 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.4378135
# 4. Updating the lambda multiplier for the flow balance: 0.0058500664
#
# iteration_step: 88
# 1. Updating the generalized travel costs: [24.976023]
# 2. Updating the optimal path flows: [ 26.556335   125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.44278952
# 4. Updating the lambda multiplier for the flow balance: 0.005920005
#
# iteration_step: 89
# 1. Updating the generalized travel costs: [24.976173]
# 2. Updating the optimal path flows: [ 26.55573038 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.4477657
# 4. Updating the lambda multiplier for the flow balance: 0.0059792474
#
# iteration_step: 90
# 1. Updating the generalized travel costs: [24.976133]
# 2. Updating the optimal path flows: [ 26.55524979 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.45274183
# 4. Updating the lambda multiplier for the flow balance: 0.0060419915
# iteration_step: 91
# 1. Updating the generalized travel costs: [24.976116]
# 2. Updating the optimal path flows: [ 26.55468235 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.45771796
# 4. Updating the lambda multiplier for the flow balance: 0.0061065746
#
# iteration_step: 92
# 1. Updating the generalized travel costs: [24.976116]
# 2. Updating the optimal path flows: [ 26.55418135 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.46269408
# 4. Updating the lambda multiplier for the flow balance: 0.0061716535
#
# iteration_step: 93
# 1. Updating the generalized travel costs: [24.976116]
# 2. Updating the optimal path flows: [ 26.55358714 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.4676702
# 4. Updating the lambda multiplier for the flow balance: 0.006237327
#
# iteration_step: 94
# 1. Updating the generalized travel costs: [24.97611]
# 2. Updating the optimal path flows: [ 26.55307802 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.47264633
# 4. Updating the lambda multiplier for the flow balance: 0.0063039395
#
# iteration_step: 95
# 1. Updating the generalized travel costs: [24.976122]
# 2. Updating the optimal path flows: [ 26.55253484 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.47762245
# 4. Updating the lambda multiplier for the flow balance: 0.006370239
#
# iteration_step: 96
# 1. Updating the generalized travel costs: [24.976122]
# 2. Updating the optimal path flows: [ 26.5520471  125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.48259857
# 4. Updating the lambda multiplier for the flow balance: 0.006437027
#
# iteration_step: 97
# 1. Updating the generalized travel costs: [24.976122]
# 2. Updating the optimal path flows: [ 26.55154907 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.4875747
# 4. Updating the lambda multiplier for the flow balance: 0.0065043108
#
# iteration_step: 98
# 1. Updating the generalized travel costs: [24.976135]
# 2. Updating the optimal path flows: [ 26.5510254  125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.49255082
# 4. Updating the lambda multiplier for the flow balance: 0.0065711136
#
# iteration_step: 99
# 1. Updating the generalized travel costs: [24.976143]
# 2. Updating the optimal path flows: [ 26.55050858 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.49752697
# 4. Updating the lambda multiplier for the flow balance: 0.0066378633
#
# iteration_step: 100
# 1. Updating the generalized travel costs: [24.976143]
# 2. Updating the optimal path flows: [ 26.55000201 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.5025031
# 4. Updating the lambda multiplier for the flow balance: 0.006705124
#
# iteration_step: 101
# 1. Updating the generalized travel costs: [24.976143]
# 2. Updating the optimal path flows: [ 26.54949923 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.50747925
# 4. Updating the lambda multiplier for the flow balance: 0.0067728804
#
# iteration_step: 102
# 1. Updating the generalized travel costs: [24.976189]
# 2. Updating the optimal path flows: [ 26.54900033 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.51245546
# 4. Updating the lambda multiplier for the flow balance: 0.0068377075
#
# iteration_step: 103
# 1. Updating the generalized travel costs: [24.976192]
# 2. Updating the optimal path flows: [ 26.54846829 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.5174317
# 4. Updating the lambda multiplier for the flow balance: 0.0069027785
#
# iteration_step: 104
# 1. Updating the generalized travel costs: [24.976192]
# 2. Updating the optimal path flows: [ 26.54774563 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.5224079
# 4. Updating the lambda multiplier for the flow balance: 0.0069685746
#
# iteration_step: 105
# 1. Updating the generalized travel costs: [24.976192]
# 2. Updating the optimal path flows: [ 26.5474304  125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.5273841
# 4. Updating the lambda multiplier for the flow balance: 0.007034683
#
# iteration_step: 106
# 1. Updating the generalized travel costs: [24.976192]
# 2. Updating the optimal path flows: [ 26.54692344 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.5323603
# 4. Updating the lambda multiplier for the flow balance: 0.007101303
#
# iteration_step: 107
# 1. Updating the generalized travel costs: [24.976192]
# 2. Updating the optimal path flows: [ 26.54641457 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.5373365
# 4. Updating the lambda multiplier for the flow balance: 0.007168426
#
# iteration_step: 108
# 1. Updating the generalized travel costs: [24.976192]
# 2. Updating the optimal path flows: [ 26.54591647 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.54231274
# 4. Updating the lambda multiplier for the flow balance: 0.0072360532
#
# iteration_step: 109
# 1. Updating the generalized travel costs: [24.976192]
# 2. Updating the optimal path flows: [ 26.54542625 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.54728895
# 4. Updating the lambda multiplier for the flow balance: 0.0073041683
#
# iteration_step: 110
# 1. Updating the generalized travel costs: [24.976192]
# 2. Updating the optimal path flows: [ 26.54483392 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.55226517
# 4. Updating the lambda multiplier for the flow balance: 0.007372871
#
# iteration_step: 111
# 1. Updating the generalized travel costs: [24.976192]
# 2. Updating the optimal path flows: [-1.33561647e+05  1.25171936e+02]
# 3. Updating the lambda multiplier for the cost linkage: 0.54724133
# 4. Updating the lambda multiplier for the flow balance: 133.59563
#
# iteration_step: 112
# 1. Updating the generalized travel costs: [29.815277]
# 2. Updating the optimal path flows: [ 36.1432197  125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.5570566
# 4. Updating the lambda multiplier for the flow balance: 133.43672
#
# iteration_step: 113
# 1. Updating the generalized travel costs: [36.12209]
# 2. Updating the optimal path flows: [ 36.08833553 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.5731787
# 4. Updating the lambda multiplier for the flow balance: 133.27547
#
# iteration_step: 114
# 1. Updating the generalized travel costs: [36.12209]
# 2. Updating the optimal path flows: [ 36.10565555 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.5893008
# 4. Updating the lambda multiplier for the flow balance: 133.1142
#
# iteration_step: 115
# 1. Updating the generalized travel costs: [36.12209]
# 2. Updating the optimal path flows: [ 36.05911476 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.6054229
# 4. Updating the lambda multiplier for the flow balance: 132.95297
#
# iteration_step: 116
# 1. Updating the generalized travel costs: [36.12209]
# 2. Updating the optimal path flows: [ 36.05800016 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.621545
# 4. Updating the lambda multiplier for the flow balance: 132.79175
#
# iteration_step: 117
# 1. Updating the generalized travel costs: [36.013203]
# 2. Updating the optimal path flows: [ 35.99657003 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.6375582
# 4. Updating the lambda multiplier for the flow balance: 132.63058
#
# iteration_step: 118
# 1. Updating the generalized travel costs: [36.013203]
# 2. Updating the optimal path flows: [ 35.99798784 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.6535714
# 4. Updating the lambda multiplier for the flow balance: 132.46942
#
# iteration_step: 119
# 1. Updating the generalized travel costs: [35.98102]
# 2. Updating the optimal path flows: [ 35.97177419 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.66955245
# 4. Updating the lambda multiplier for the flow balance: 132.30829
#
# iteration_step: 120
# 1. Updating the generalized travel costs: [35.98102]
# 2. Updating the optimal path flows: [ 35.94241863 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.68553346
# 4. Updating the lambda multiplier for the flow balance: 132.14719
#
# iteration_step: 121
# 1. Updating the generalized travel costs: [35.98102]
# 2. Updating the optimal path flows: [ 35.92480822 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.7015145
# 4. Updating the lambda multiplier for the flow balance: 131.9861
# iteration_step: 122
# 1. Updating the generalized travel costs: [35.917103]
# 2. Updating the optimal path flows: [ 35.91692496 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.7174316
# 4. Updating the lambda multiplier for the flow balance: 131.82501
#
# iteration_step: 123
# 1. Updating the generalized travel costs: [35.90038]
# 2. Updating the optimal path flows: [ 35.87846787 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.733332
# 4. Updating the lambda multiplier for the flow balance: 131.66397
#
# iteration_step: 124
# 1. Updating the generalized travel costs: [35.849094]
# 2. Updating the optimal path flows: [ 35.8544896  125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.7491811
# 4. Updating the lambda multiplier for the flow balance: 131.50294
#
# iteration_step: 125
# 1. Updating the generalized travel costs: [35.849094]
# 2. Updating the optimal path flows: [ 35.84154976 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.7650302
# 4. Updating the lambda multiplier for the flow balance: 131.34193
#
# iteration_step: 126
# 1. Updating the generalized travel costs: [35.849094]
# 2. Updating the optimal path flows: [ 35.81312464 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.7808793
# 4. Updating the lambda multiplier for the flow balance: 131.18095
#
# iteration_step: 127
# 1. Updating the generalized travel costs: [35.798958]
# 2. Updating the optimal path flows: [ 35.79697268 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.7966783
# 4. Updating the lambda multiplier for the flow balance: 131.01999
#
# iteration_step: 128
# 1. Updating the generalized travel costs: [35.785145]
# 2. Updating the optimal path flows: [ 35.77146883 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.81246346
# 4. Updating the lambda multiplier for the flow balance: 130.85905
#
# iteration_step: 129
# 1. Updating the generalized travel costs: [35.785145]
# 2. Updating the optimal path flows: [ 35.75936767 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.8282486
# 4. Updating the lambda multiplier for the flow balance: 130.69814
#
# iteration_step: 130
# 1. Updating the generalized travel costs: [35.76013]
# 2. Updating the optimal path flows: [ 35.73421425 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.84400874
# 4. Updating the lambda multiplier for the flow balance: 130.53723
#
# iteration_step: 131
# 1. Updating the generalized travel costs: [35.71388]
# 2. Updating the optimal path flows: [ 35.70769158 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.8597226
# 4. Updating the lambda multiplier for the flow balance: 130.37636
#
# iteration_step: 132
# 1. Updating the generalized travel costs: [35.69019]
# 2. Updating the optimal path flows: [ 35.69232865 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.8754128
# 4. Updating the lambda multiplier for the flow balance: 130.2155
#
# iteration_step: 133
# 1. Updating the generalized travel costs: [35.69019]
# 2. Updating the optimal path flows: [ 35.64112847 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.891103
# 4. Updating the lambda multiplier for the flow balance: 130.05469
#
# iteration_step: 134
# 1. Updating the generalized travel costs: [35.69019]
# 2. Updating the optimal path flows: [ 35.62024868 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.90679324
# 4. Updating the lambda multiplier for the flow balance: 129.8939
#
# iteration_step: 135
# 1. Updating the generalized travel costs: [35.69019]
# 2. Updating the optimal path flows: [ 35.6353687  125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.92248344
# 4. Updating the lambda multiplier for the flow balance: 129.73311
#
# iteration_step: 136
# 1. Updating the generalized travel costs: [35.620186]
# 2. Updating the optimal path flows: [ 35.61550428 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.9381036
# 4. Updating the lambda multiplier for the flow balance: 129.57233
#
# iteration_step: 137
# 1. Updating the generalized travel costs: [35.620186]
# 2. Updating the optimal path flows: [ 35.59756454 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.9537238
# 4. Updating the lambda multiplier for the flow balance: 129.41156
#
# iteration_step: 138
# 1. Updating the generalized travel costs: [35.580814]
# 2. Updating the optimal path flows: [ 35.58086067 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.9693046
# 4. Updating the lambda multiplier for the flow balance: 129.25081
#
# iteration_step: 139
# 1. Updating the generalized travel costs: [35.580814]
# 2. Updating the optimal path flows: [ 35.56576632 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 0.98488545
# 4. Updating the lambda multiplier for the flow balance: 129.09007
#
# iteration_step: 140
# 1. Updating the generalized travel costs: [35.580814]
# 2. Updating the optimal path flows: [ 35.54485543 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.0004662
# 4. Updating the lambda multiplier for the flow balance: 128.92937
#
# iteration_step: 141
# 1. Updating the generalized travel costs: [35.52912]
# 2. Updating the optimal path flows: [ 35.52676868 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.0159954
# 4. Updating the lambda multiplier for the flow balance: 128.76868
#
# iteration_step: 142
# 1. Updating the generalized travel costs: [35.512653]
# 2. Updating the optimal path flows: [ 35.52672834 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.0315081
# 4. Updating the lambda multiplier for the flow balance: 128.60799
#
# iteration_step: 143
# 1. Updating the generalized travel costs: [35.504578]
# 2. Updating the optimal path flows: [ 35.49772326 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.0470127
# 4. Updating the lambda multiplier for the flow balance: 128.44733
#
# iteration_step: 144
# 1. Updating the generalized travel costs: [35.504578]
# 2. Updating the optimal path flows: [ 35.48557024 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.0625173
# 4. Updating the lambda multiplier for the flow balance: 128.28668
#
# iteration_step: 145
# 1. Updating the generalized travel costs: [35.46328]
# 2. Updating the optimal path flows: [ 35.47765427 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.0779805
# 4. Updating the lambda multiplier for the flow balance: 128.12604
#
# iteration_step: 146
# 1. Updating the generalized travel costs: [35.46328]
# 2. Updating the optimal path flows: [ 35.46868162 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.0934438
# 4. Updating the lambda multiplier for the flow balance: 127.96541
#
# iteration_step: 147
# 1. Updating the generalized travel costs: [35.46328]
# 2. Updating the optimal path flows: [ 35.44619601 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.108907
# 4. Updating the lambda multiplier for the flow balance: 127.8048
#
# iteration_step: 148
# 1. Updating the generalized travel costs: [35.46328]
# 2. Updating the optimal path flows: [ 35.44225895 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.1243702
# 4. Updating the lambda multiplier for the flow balance: 127.644196
#
# iteration_step: 149
# 1. Updating the generalized travel costs: [35.40633]
# 2. Updating the optimal path flows: [ 35.40754748 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.1397766
# 4. Updating the lambda multiplier for the flow balance: 127.48363
#
# iteration_step: 150
# 1. Updating the generalized travel costs: [35.40017]
# 2. Updating the optimal path flows: [ 35.39716945 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.1551768
# 4. Updating the lambda multiplier for the flow balance: 127.32307
#
# iteration_step: 151
# 1. Updating the generalized travel costs: [35.40017]
# 2. Updating the optimal path flows: [ 35.38333747 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.1705769
# 4. Updating the lambda multiplier for the flow balance: 127.16252
#
# iteration_step: 152
# 1. Updating the generalized travel costs: [35.356556]
# 2. Updating the optimal path flows: [ 35.37636469 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.1859335
# 4. Updating the lambda multiplier for the flow balance: 127.00198
# iteration_step: 153
# 1. Updating the generalized travel costs: [35.356556]
# 2. Updating the optimal path flows: [ 35.35506651 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.20129
# 4. Updating the lambda multiplier for the flow balance: 126.84147
#
# iteration_step: 154
# 1. Updating the generalized travel costs: [35.351128]
# 2. Updating the optimal path flows: [ 35.34005544 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.2166412
# 4. Updating the lambda multiplier for the flow balance: 126.68097
#
# iteration_step: 155
# 1. Updating the generalized travel costs: [35.351128]
# 2. Updating the optimal path flows: [ 35.33191701 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.2319924
# 4. Updating the lambda multiplier for the flow balance: 126.52048
#
# iteration_step: 156
# 1. Updating the generalized travel costs: [35.298233]
# 2. Updating the optimal path flows: [ 35.30783776 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.2472906
# 4. Updating the lambda multiplier for the flow balance: 126.36001
#
# iteration_step: 157
# 1. Updating the generalized travel costs: [35.294235]
# 2. Updating the optimal path flows: [ 35.30250458 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.2625848
# 4. Updating the lambda multiplier for the flow balance: 126.19955
#
# iteration_step: 158
# 1. Updating the generalized travel costs: [35.28633]
# 2. Updating the optimal path flows: [ 35.28338674 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.2778711
# 4. Updating the lambda multiplier for the flow balance: 126.0391
#
# iteration_step: 159
# 1. Updating the generalized travel costs: [35.28633]
# 2. Updating the optimal path flows: [ 35.27215306 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.2931575
# 4. Updating the lambda multiplier for the flow balance: 125.87867
#
# iteration_step: 160
# 1. Updating the generalized travel costs: [35.28633]
# 2. Updating the optimal path flows: [ 35.2671874  125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.3084438
# 4. Updating the lambda multiplier for the flow balance: 125.71824
#
# iteration_step: 161
# 1. Updating the generalized travel costs: [35.243584]
# 2. Updating the optimal path flows: [ 35.25379659 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.3236873
# 4. Updating the lambda multiplier for the flow balance: 125.55782
#
# iteration_step: 162
# 1. Updating the generalized travel costs: [35.243584]
# 2. Updating the optimal path flows: [ 35.23275536 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.3389308
# 4. Updating the lambda multiplier for the flow balance: 125.39743
#
# iteration_step: 163
# 1. Updating the generalized travel costs: [35.243584]
# 2. Updating the optimal path flows: [ 35.22071361 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.3541744
# 4. Updating the lambda multiplier for the flow balance: 125.237045
#
# iteration_step: 164
# 1. Updating the generalized travel costs: [35.19929]
# 2. Updating the optimal path flows: [ 35.21285933 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.3693737
# 4. Updating the lambda multiplier for the flow balance: 125.076675
#
# iteration_step: 165
# 1. Updating the generalized travel costs: [35.19929]
# 2. Updating the optimal path flows: [ 35.19577425 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.384573
# 4. Updating the lambda multiplier for the flow balance: 124.91632
#
# iteration_step: 166
# 1. Updating the generalized travel costs: [35.19929]
# 2. Updating the optimal path flows: [ 35.18332936 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.3997723
# 4. Updating the lambda multiplier for the flow balance: 124.755974
#
# iteration_step: 167
# 1. Updating the generalized travel costs: [35.19929]
# 2. Updating the optimal path flows: [ 35.17828411 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.4149716
# 4. Updating the lambda multiplier for the flow balance: 124.595634
#
# iteration_step: 168
# 1. Updating the generalized travel costs: [35.19929]
# 2. Updating the optimal path flows: [ 35.12603166 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.4301709
# 4. Updating the lambda multiplier for the flow balance: 124.43535
#
# iteration_step: 169
# 1. Updating the generalized travel costs: [35.123615]
# 2. Updating the optimal path flows: [ 35.15446886 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.4452945
# 4. Updating the lambda multiplier for the flow balance: 124.27503
#
# iteration_step: 170
# 1. Updating the generalized travel costs: [35.123615]
# 2. Updating the optimal path flows: [ 35.15427674 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.4604181
# 4. Updating the lambda multiplier for the flow balance: 124.114716
#
# iteration_step: 171
# 1. Updating the generalized travel costs: [35.123615]
# 2. Updating the optimal path flows: [ 35.12577286 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.4755417
# 4. Updating the lambda multiplier for the flow balance: 123.95443
#
# iteration_step: 172
# 1. Updating the generalized travel costs: [35.105793]
# 2. Updating the optimal path flows: [ 35.12973801 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.4906476
# 4. Updating the lambda multiplier for the flow balance: 123.79414
#
# iteration_step: 173
# 1. Updating the generalized travel costs: [35.105793]
# 2. Updating the optimal path flows: [ 35.10352773 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.5057534
# 4. Updating the lambda multiplier for the flow balance: 123.63388
#
# iteration_step: 174
# 1. Updating the generalized travel costs: [35.105793]
# 2. Updating the optimal path flows: [ 35.10331539 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.5208592
# 4. Updating the lambda multiplier for the flow balance: 123.47362
#
# iteration_step: 175
# 1. Updating the generalized travel costs: [35.063553]
# 2. Updating the optimal path flows: [ 35.10045614 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.5359228
# 4. Updating the lambda multiplier for the flow balance: 123.313354
#
# iteration_step: 176
# 1. Updating the generalized travel costs: [35.063553]
# 2. Updating the optimal path flows: [ 35.05435038 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.5509863
# 4. Updating the lambda multiplier for the flow balance: 123.15314
#
# iteration_step: 177
# 1. Updating the generalized travel costs: [35.05791]
# 2. Updating the optimal path flows: [ 35.0803808  125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.5660442
# 4. Updating the lambda multiplier for the flow balance: 122.9929
#
# iteration_step: 178
# 1. Updating the generalized travel costs: [35.05791]
# 2. Updating the optimal path flows: [ 35.0480908  125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.5811021
# 4. Updating the lambda multiplier for the flow balance: 122.83269
#
# iteration_step: 179
# 1. Updating the generalized travel costs: [35.05791]
# 2. Updating the optimal path flows: [ 35.03735621 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.59616
# 4. Updating the lambda multiplier for the flow balance: 122.67249
#
# iteration_step: 180
# 1. Updating the generalized travel costs: [35.00417]
# 2. Updating the optimal path flows: [ 35.04082115 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.6111642
# 4. Updating the lambda multiplier for the flow balance: 122.51229
#
# iteration_step: 181
# 1. Updating the generalized travel costs: [35.012173]
# 2. Updating the optimal path flows: [ 35.03824319 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.6261764
# 4. Updating the lambda multiplier for the flow balance: 122.3521
#
# iteration_step: 182
# 1. Updating the generalized travel costs: [34.997784]
# 2. Updating the optimal path flows: [ 35.01918875 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.6411742
# 4. Updating the lambda multiplier for the flow balance: 122.19192
#
# iteration_step: 183
# 1. Updating the generalized travel costs: [34.997784]
# 2. Updating the optimal path flows: [ 35.0085055  125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.656172
# 4. Updating the lambda multiplier for the flow balance: 122.03175
# iteration_step: 184
# 1. Updating the generalized travel costs: [34.997784]
# 2. Updating the optimal path flows: [ 34.99692839 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.6711699
# 4. Updating the lambda multiplier for the flow balance: 121.8716
#
# iteration_step: 185
# 1. Updating the generalized travel costs: [34.955666]
# 2. Updating the optimal path flows: [ 34.95657656 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.6861255
# 4. Updating the lambda multiplier for the flow balance: 121.71149
#
# iteration_step: 186
# 1. Updating the generalized travel costs: [34.95734]
# 2. Updating the optimal path flows: [ 34.97753395 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.7010828
# 4. Updating the lambda multiplier for the flow balance: 121.55135
#
# iteration_step: 187
# 1. Updating the generalized travel costs: [34.95734]
# 2. Updating the optimal path flows: [ 34.96815025 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.7160401
# 4. Updating the lambda multiplier for the flow balance: 121.39123
#
# iteration_step: 188
# 1. Updating the generalized travel costs: [34.932076]
# 2. Updating the optimal path flows: [ 34.95187038 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.7309722
# 4. Updating the lambda multiplier for the flow balance: 121.23112
#
# iteration_step: 189
# 1. Updating the generalized travel costs: [34.932297]
# 2. Updating the optimal path flows: [ 34.94086992 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.7459044
# 4. Updating the lambda multiplier for the flow balance: 121.07102
#
# iteration_step: 190
# 1. Updating the generalized travel costs: [34.929985]
# 2. Updating the optimal path flows: [ 34.93727074 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.7608345
# 4. Updating the lambda multiplier for the flow balance: 120.91093
#
# iteration_step: 191
# 1. Updating the generalized travel costs: [34.929985]
# 2. Updating the optimal path flows: [ 34.92909625 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.7757645
# 4. Updating the lambda multiplier for the flow balance: 120.75084
#
# iteration_step: 192
# 1. Updating the generalized travel costs: [34.929985]
# 2. Updating the optimal path flows: [ 34.91967315 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.7906945
# 4. Updating the lambda multiplier for the flow balance: 120.59076
#
# iteration_step: 193
# 1. Updating the generalized travel costs: [34.872204]
# 2. Updating the optimal path flows: [ 34.90462881 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.8055667
# 4. Updating the lambda multiplier for the flow balance: 120.430695
#
# iteration_step: 194
# 1. Updating the generalized travel costs: [34.872204]
# 2. Updating the optimal path flows: [ 34.89660207 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.8204389
# 4. Updating the lambda multiplier for the flow balance: 120.270645
#
# iteration_step: 195
# 1. Updating the generalized travel costs: [34.872204]
# 2. Updating the optimal path flows: [ 34.89258626 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.835311
# 4. Updating the lambda multiplier for the flow balance: 120.110596
#
# iteration_step: 196
# 1. Updating the generalized travel costs: [34.872204]
# 2. Updating the optimal path flows: [ 34.86475419 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.8501832
# 4. Updating the lambda multiplier for the flow balance: 119.95058
#
# iteration_step: 197
# 1. Updating the generalized travel costs: [34.843567]
# 2. Updating the optimal path flows: [ 34.86724377 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.8650268
# 4. Updating the lambda multiplier for the flow balance: 119.79055
#
# iteration_step: 198
# 1. Updating the generalized travel costs: [34.845215]
# 2. Updating the optimal path flows: [ 34.86402984 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.8798721
# 4. Updating the lambda multiplier for the flow balance: 119.63053
#
# iteration_step: 199
# 1. Updating the generalized travel costs: [34.845215]
# 2. Updating the optimal path flows: [ 34.84987083 125.17193604]
# 3. Updating the lambda multiplier for the cost linkage: 1.8947173
# 4. Updating the lambda multiplier for the flow balance: 119.47053
